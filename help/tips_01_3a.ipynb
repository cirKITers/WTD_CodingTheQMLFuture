# %% [markdown]
# # Tips for task 3a) in worksheet 01

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tip 1</h2>
#     <details>
#     <summary>Click here!</summary>
#
#   Besides rotating around the y-axis, there are also the possibilities to use [$R_Z$](https://docs.pennylane.ai/en/stable/code/api/pennylane.RZ.html) and [$R_X$](https://docs.pennylane.ai/en/stable/code/api/pennylane.RX.html). Please go ahead and check how the amplitudes of the final state change and what is the most reasonable rotation to use for our current use case.
#
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-check" style="font-size:36px"></i> &nbsp; Exemplary Solution </h2>
#     <details>
#     <summary>Click here!</summary>
#
#   ```python
#   def angle_encoding(value, n_qubits):
#     """
#     Encode an integer value using basis encoding.
#     """
#
#     @qml.qnode(dev)
#     def circuit():
#         for position, feature in enumerate(features):
#           qml.RY(feature * np.pi, wires=position % n_qubits)
#         return qml.state()
#
#     return circuit
#   ```
# </details>
# </div>
