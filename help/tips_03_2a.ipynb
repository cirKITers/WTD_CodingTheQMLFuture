# %% [markdown]
# # Tips for task 2a) in worksheet 03

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tip 1</h2>
#     <details>
#     <summary>Click here!</summary>
#
#   Parameters are reused for different U3 gates again.
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tip 2</h2>
#     <details>
#     <summary>Click here!</summary>
#
#   You can perform a mid-circuit measurment with
#
#   ```python
#   outcome = qml.measure(wire)
#   ```
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-info">
#   <h2><i class="fas fa-life-ring" style="font-size:36px"></i> &nbsp; Tip 3</h2>
#     <details>
#     <summary>Click here!</summary>
#
#   Please take care that some quantum devices don't support mid-circuit measurements. However, it is still possible to restructure the circuit to fulfil the same operation as mid-circuit measurements.
#
# </details>
# </div>

# %% [markdown]
# <div class="alert alert-success">
#   <h2><i class="fas fa-check" style="font-size:36px"></i> &nbsp; Exemplary Solution </h2>
#     <details>
#     <summary>Click here!</summary>
#
#   ```python
#   def pooling_layer(weights, wires):
#     """
#     Apply a quantum pooling layer.
#     """
#     n_wires = len(wires)
#     assert n_wires >= 2, "Pooling layer requires at least 2 qubits"
#
#     for index, wire in enumerate(wires):
#         if index % 2 == 1 and index < n_wires:
#             m_outcome = qml.measure(wire)
#             qml.cond(m_outcome, qml.U3)(*weights, wires=wires[index - 1])
#   ```
# </details>
# </div>
